# %% [markdown]
# ## **Maestría en Inteligencia Artificial Aplicada**
# ### **Curso: Inteligencia Artificial y Aprendizaje Automático**
# #### Tecnológico de Monterrey
# #### Prof Luis Eduardo Falcón Morales
#
# ### **Actividad de la Semana:**
#
# ### **Descomposición en Valores Singulares (SVD) y Sistemas de Recomendación**

# %% [markdown]
# **Esta Actividad deberá resolverse de manera individual.**
#
# **Nombre y matrícula:** Ramón Orlando Cabrera Cabrera A01796634

# %% [markdown]
# # **Introducción**

# %%
# Agrega aquí todas las librerías y paquetes adicionales que requieras.

import numpy as np
import pandas as pd


None

# %% [markdown]
# * ### **Liga de datos de la UCI: "Restaurant & consumer data".**
#
# https://archive.ics.uci.edu/dataset/232/restaurant+consumer+data
#
# * ### **Del archivo comprimido "RCdata.zip" necesitamos solamente "rating_final.csv" y "geoplaces2.csv".**
#
# * ### **NOTA: Al igual que con las variables numéricas, la información de variables con información de texto (strings) tiene sus propias técnicas de limpieza y transformación que podrás estudiar en cursos posteriores (en particular en el curso optativo de Procesamiento de Lenguaje Natural). No es el objetivo de este curso adentrarnos en dichas técnicas, pero sí requerimos hacer unos ajustes de limpieza para poder llevar a cabo la presente actividad. En particular, en la pregunta 2 te indicaré directamente cuál es el ajuste que hay que realizar para que el algoritmo de factorización SVD pueda funcionar más adelante.**

# %%
# Cargamos los archivos de la página de la UCI para construir
# nuestra matriz de utilidad:

data_rating = pd.read_csv("https://raw.githubusercontent.com/A01796634/Inteligencia-artificial-y-aprendizaje-autom-tico/main/rating_final.csv", header='infer', sep=",")

data_geo = pd.read_csv("https://raw.githubusercontent.com/A01796634/Inteligencia-artificial-y-aprendizaje-autom-tico/main/geoplaces2.csv", header='infer',  encoding='latin-1')

print(data_rating.shape, data_geo.shape)
# Out:
# (1161, 5) (130, 21)

# %% [markdown]
# # **Ejercicio - 1**

# %% [markdown]
# * ### **Explica cuál es el propósito del argumento "encoding" al cargar el segundo archivo. En particular, explica el error que te genera si omitimos dicho argumento y por qué el primer archivo no lo requiere.**

# %% [markdown]
# ++++++++ Inicia la sección de agregar texto: +++++++++++
#
# El argumento encoding en la función pd.read_csv() permite indicar la codificación de caracteres utilizada por el archivo. Su propósito es asegurar que caracteres especiales, como acentos o símbolos propios de determinados idiomas, sean interpretados correctamente. Si se omite este argumento en un archivo cuya codificación no coincide con la predeterminada (UTF-8), puede producirse un error del tipo UnicodeDecodeError, debido a que Python no logra decodificar algunos bytes presentes en el archivo. En el caso del segundo archivo, fue necesario especificar encoding='latin-1' porque contenía caracteres codificados bajo ese estándar. El primer archivo no requirió dicho parámetro porque estaba codificado en un formato compatible con UTF-8, por lo que Pandas pudo leerlo correctamente sin información adicional. De acuerdo con McKinney (2022), el parámetro encoding de read_csv() permite manejar archivos con diferentes esquemas de codificación y evitar errores durante la importación de datos.
#
# ***Referencia***
#
# McKinney, W. (2022). Python for Data Analysis: Data Wrangling with Pandas, NumPy, and Jupyter (3.ª ed.). O'Reilly Media.
# ++++++++ Termina la sección de agregar texto. +++++++++++

# %%
# Veamos la lista de los nombres de los restaurantes de nuestros datos.
# Todos ellos son restaurantes ubicados en alguna ciudad del país de México:

data_geo['name'].values
# Out:
# array(['Kiku Cuernavaca', 'puesto de tacos', 'El Rincón de San Francisco',
#        'little pizza Emilio Portes Gil', 'carnitas_mata',
#        'Restaurant los Compadres', 'Taqueria EL amigo ', 'shi ro ie',
#        'Pollo_Frito_Buenos_Aires', 'la Estrella de Dimas',
#        'Restaurante 75', 'Abondance Restaurante Bar',
#        'El angel Restaurante', 'Restaurante Pueblo Bonito',
#        'Mcdonalds Parque Tangamanga', 'Tortas y hamburguesas el gordo',
#        'Sirlone', 'rockabilly ', 'Unicols Pizza', 'TACOS EL GUERO',
#        'Restaurant El Muladar de Calzada', 'La Posada del Virrey',
#        'Restaurant and Bar and Clothesline Carlos N Charlies', 'KFC',
#        'Giovannis', 'Restaurant Oriental Express', 'Mariscos Tia Licha',
#        'cafe ambar', 'Restaurante la Gran Via', 'don burguers',
#        'Restaurante y Pescaderia Tampico', 'Rincon del Bife',
#        'La Fontana Pizza Restaurante and Cafe',
#        'Restaurante la Estrella de Dima', 'El Rincon de San Francisco',
#        'Preambulo Wifi Zone Cafe', 'El Herradero Restaurante and Bar',
#        'Koye Sushi', 'Restaurant Teely', 'la parroquia', 'Luna Cafe',
#        'Hamburguesas La perica', 'Restaurante El Reyecito', 'churchs',
#        'Dominos Pizza', 'el pueblito', 'emilianos',
#        'Restaurant Bar Hacienda los Martinez', 'Vips',
#        'Restaurante Alhondiga', 'los Toneles', 'Restaurant los Pinos',
#        'Restaurante Guerra', 'Michiko Restaurant Japones',
#        'Restaurante Marisco Sam',
#        'la Cochinita Pibil Restaurante Yucateco', 'Potzocalli',
#        'Restaurante la Parroquia Potosina', 'El Oceano Dorado',
#        'Restaurante El Chivero S.A. de C.V.', 'Restaurant la Chalita',
#        'El Club', 'Gordas de morales', 'Restaurante Versalles', 'Subway',
#        'La Cantina Restaurante', 'Cenaduria El RincÃ³n de Tlaquepaque',
#        'Los Vikingos', 'Hamburguesas Valle Dorado', 'la Cantina',
#        'dairy queen', 'Arrachela Grill', 'vips', 'palomo tec',
#        'Restaurante Casa de las Flores', 'VIPS', 'TACOS CORRECAMINOS',
#        'Restaurant Wu Zhuo Yi', 'El Mundo de la Pasta',
#        'Restaurante la Cantina', 'Gorditas Doa Gloria',
#        'el lechon potosino ', 'Restaurante Bar Fu-hao', 'tortas hawai',
#        'Carls Jr', 'Hamburguesas saul', 'Carreton de Flautas y Migadas',
#        'Rincon Huasteco', 'El cotorreo', 'Gorditas Dona Tota',
#        'Pizzeria Julios', 'Chilis Cuernavaca', 'Cafe Chaires',
#        'tacos los volcanes', 'Little Cesarz', 'cafe punta del cielo',
#        'tacos de la estacion', 'Restaurant Orizatlan',
#        'Restaurant Familiar El Chino', 'Restaurant de Mariscos de Picon',
#        'Sanborns Casa Piedra', 'La Estrella de Dimas', 'pizza clasica',
#        'Carnitas Mata  Calle 16 de Septiembre',
#        'Restaurante de Mariscos la Langosta',
#        'Restaurante Bar El Gallinero', 'puesto de gorditas', 'Log Yin',
#        'Mariscos El Pescador', 'carnitas mata calle Emilio Portes Gil',
#        'crudalia', 'tacos de barbacoa enfrente del Tec',
#        'Restaurant Las Mananitas', 'Restaurante El Cielo Potosino',
#        'Mikasa', 'Cafeteria cenidet', 'Restaurante Tiberius',
#        'Cabana Huasteca', 'Gorditas Dona Tota',
#        'Cafeteria y Restaurant El Pacifico', 'La Virreina',
#        'Tortas Locas Hipocampo', 'tacos abi', 'la perica hamburguesa',
#        'McDonalds Centro', 'Chaires', 'Sushi Itto', 'Paniroles',
#        'Restaurant Bar Coty y Pablo', 'sirloin stockade'], dtype=object)

# %% [markdown]
# #### **Para que el algoritmo SVD funcione, cada registro (renglón) debe estar asociado a un restaurante con un nombre diferente.**

# %% [markdown]
# ### **Algunos comentarios acerca de estos nombres. Para obtener la información de los siguientes comentarios en realidad requerimos algunas técnicas de procesamiento de lenguaje natural, pero como te comentaba, por el momento te las proporciono directamente para no distraernos con dichas técnicas de limpieza:**
#
# *   ### **En la presente actividad generaremos un sistema de recomendación con base a la evaluación de varias características del servicio o tipo de comida de cada restaurante. Por el momento no tomaremos en cuenta la ubicación para generar nuestro sistema de recomendación, pero sí necesitamos aclarar ciertos puntos que menciono a continuación.**
#
# * ### **La longitud y latitud es información que encuentras en el archivo geoplaces2.csv y son las coordenadas de la ubicación geográfica de cada restaurante. Se puede verificar que todas las coordenadas son diferentes, es decir, que todos los registros (renglones) contienen información de restaurantes ubicados en diferentes lugares de México.**
#
# *   ### **Algunos restaurantes pertenezcan a una misma franquicia, como por ejemplo, Vips.**
#
# *   ### **Para los fines de este ejercicio, cada registro de la base de datos lo consideraremos como un negocio diferente, independientemente de que pertenezcan a una misma franquicia. Así, en particular en el caso de Vips, existen tres restaurantes en esta lista capturados con los nombres: VIPS, Vips y vips. Por sus coordenadas de latitud y longitud sabemos que están ubicados en San Luis Potosí, Cuernavaca y Ciudad Victoria, tres ciudades diferentes de México. Como estos tres nombres están escritos de manera diferente, al momento de procesarlos con el algoritmo de SVD se estarán considerando como tres restaurantes diferentes. Por el momento es lo que queremos y por lo tanto no haremos ajustes en dichos nombres.**
#
# *   ### **En el archivo existen más restaurantes pertenecientes a otras franquicias que han sido capturados también de manera diferente y nuevamente, así los dejaremos. Sin embargo, en el caso de 'Gorditas Dona Tota', dos de estos restaurantes están ubicados en Cd.Victoria y están escritos exactamente de la misma forma. Si los dejamos de esta manera, nuestro algoritmo SVD no funcionará, por ello, debes cambiar el nombre de uno de ellos como se te indica a continuación.**

# %% [markdown]
# # **Ejercicio - 2**

# %% [markdown]
# * ### **Encuentra los índices de los dos restaurantes registrados exactamente con el mismo nombre de 'Gorditas Dona Tota' y cambia el nombre del que tiene el mayor índice en data_geo[name], al de  'Gorditas Dona Tota 2'.**

# %%
# Ejercicio-2

# ************* Inlcuye aquí tu código:*****************************


# Incluyamos en la siguiente variable la lista de todos los índices
# de restaurantes con exactamente el mismo nombre de 'Gorditas Dona Tota':

indices_Dona_Tota = data_geo.index[data_geo['name'] == 'Gorditas Dona Tota'].tolist()

# Cambio de nombre mayor índice
data_geo.loc[max(indices_Dona_Tota), 'name'] = 'Gorditas Dona Tota 2'


# *********** Aquí termina la sección de agregar código *************

print('Desplegando los nombres de los dos restaurantes con el ajuste:\n', data_geo.loc[indices_Dona_Tota, 'name'])
# Out:
# Desplegando los nombres de los dos restaurantes con el ajuste:
#  89       Gorditas Dona Tota
# 118    Gorditas Dona Tota 2
# Name: name, dtype: object

# %% [markdown]
# ***Análisis:*** Se identificaron dos restaurantes con el nombre idéntico 'Gorditas Dona Tota', localizados en los índices 89 y 118. Para evitar duplicidades y garantizar que cada restaurante tenga un identificador único, se modificó el nombre del registro con el índice mayor, quedando como 'Gorditas Dona Tota 2'. Este ajuste permite que el algoritmo SVD procese correctamente la información y genere recomendaciones sin ambigüedades.

# %%
# Al momento tenemos los siguientes DataFrames. Del primer archivo
# tenemos la evaluación general, la de la comida y la del servicio:

data_rating.head(3)
# Out:
#   userID  placeID  rating  food_rating  service_rating
# 0  U1077   135085       2            2               2
# 1  U1077   135038       2            2               1
# 2  U1077   132825       2            2               2

# %%
# Y del segundo archivo obtenemos información diversa de cada restaurante:

data_geo.head(2).T
# Out:
#                                                                 0  \
# placeID                                                    134999
# latitude                                                18.915421
# longitude                                              -99.184871
# the_geom_meter  0101000020957F000088568DE356715AC138C0A525FC46...
# name                                              Kiku Cuernavaca
# address                                                Revolucion
# city                                                   Cuernavaca
# state                                                     Morelos
# country                                                    Mexico
# fax                                                             ?
# zip                                                             ?
# alcohol                                         No_Alcohol_Served
# smoking_area                                                 none
# dress_code                                               informal
# accessibility                                    no_accessibility
# price                                                      medium
# url                                         kikucuernavaca.com.mx
# Rambience                                                familiar
# franchise                                                       f
# area                                                       closed
# other_services                                               none
#
#                                                                 1
# placeID                                                    132825
# latitude                                                22.147392
# longitude                                             -100.983092
# the_geom_meter  0101000020957F00001AD016568C4858C1243261274BA5...
# name                                              puesto de tacos
# address                    esquina santos degollado y leon guzman
# city                                                       s.l.p.
# state                                                      s.l.p.
# country                                                    mexico
# fax                                                             ?
# zip                                                         78280
# alcohol                                         No_Alcohol_Served
# smoking_area                                                 none
# dress_code                                               informal
# accessibility                                          completely
# price                                                         low
# url                                                             ?
# Rambience                                                familiar
# franchise                                                       f
# area                                                         open
# other_services                                               none

# %% [markdown]
# ***Análisis:*** Actualmente se dispone de dos conjuntos de datos complementarios. El DataFrame data_rating contiene las valoraciones realizadas por los usuarios a los restaurantes, incluyendo la evaluación general, la calidad de la comida y la calidad del servicio. Por otra parte, el DataFrame data_geo almacena información descriptiva de cada restaurante, como su ubicación geográfica, nombre, dirección, ciudad, estado, nivel de precio y otros atributos relevantes. La combinación de ambos conjuntos de datos permite construir un sistema de recomendación basado en las preferencias de los usuarios y en las características de los establecimientos.

# %% [markdown]
# # **Ejercicio - 3**

# %% [markdown]
# * ### **De cada uno de estos archivos selecciona y combina las variables adecuadas para obtener un nuevo DataFrame con 4 columnas: el ID de usuario (userID), el ID del restaurante (placeID), la calificación general (rating) y el nombre del restaurante (name). A este nuevo DataFrame llamarlo df_combinado.**

# %%
# Ejercicio 3:

# ************* Inlcuye aquí tu código:*****************************
rating_df = data_rating[['userID', 'placeID', 'rating']]
geo_df = data_geo[['placeID', 'name']]


df_combinado = pd.merge(rating_df, geo_df, on='placeID')



# *********** Aquí termina la sección de agregar código *************


# Despleguemos la dimensión y los primeros renglones de este DataFrame:

print(df_combinado.shape)
df_combinado.head()
# Out:
# (1161, 4)
#   userID  placeID  rating                     name
# 0  U1077   135085       2   Tortas Locas Hipocampo
# 1  U1077   135038       2    Restaurant la Chalita
# 2  U1077   132825       2          puesto de tacos
# 3  U1077   135060       1  Restaurante Marisco Sam
# 4  U1068   135104       1                     vips

# %% [markdown]
# ***Análisis:*** Se construyó un nuevo DataFrame denominado df_combinado, el cual integra la información de las evaluaciones realizadas por los usuarios con los nombres de los restaurantes. El conjunto de datos resultante contiene 1161 registros y cuatro variables: identificador del usuario (userID), identificador del restaurante (placeID), calificación general (rating) y nombre del restaurante (name). Esta integración permite relacionar las preferencias de los usuarios con los establecimientos evaluados, constituyendo la base para la implementación del sistema de recomendación mediante factorización matricial.

# %% [markdown]
# # **Ejercicio - 4**

# %%
# Ejercicio 4:

#    Define la matriz de utilidad cuyos renglones sean los nombres de los
#    restaurantes, las columnas los IDs de los usuarios y las entradas la
#    evaluación general (rating). La llamaremos "UtMx_rating".


# ************* Inlcuye aquí tu código:*****************************


UtMx_rating = df_combinado.pivot_table(
    index='name',
    columns='userID',
    values='rating'
)


# *********** Aquí termina la sección de agregar código *************


print('Dimensión de la matriz de Utilidad:')
print('(restaurantes, usuarios) =', (UtMx_rating.shape))
UtMx_rating.head()
# Out:
# Dimensión de la matriz de Utilidad:
# (restaurantes, usuarios) = (130, 138)
# userID                     U1001  U1002  U1003  U1004  U1005  U1006  U1007  \
# name
# Abondance Restaurante Bar    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Arrachela Grill              NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Cabana Huasteca              NaN    NaN    2.0    NaN    NaN    NaN    NaN
# Cafe Chaires                 NaN    NaN    NaN    NaN    NaN    1.0    1.0
# Cafeteria cenidet            NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# userID                     U1008  U1009  U1010  ...  U1129  U1130  U1131  \
# name                                            ...
# Abondance Restaurante Bar    1.0    NaN    NaN  ...    NaN    NaN    NaN
# Arrachela Grill              NaN    NaN    NaN  ...    NaN    NaN    NaN
# Cabana Huasteca              NaN    1.0    NaN  ...    NaN    NaN    NaN
# Cafe Chaires                 NaN    NaN    NaN  ...    NaN    NaN    NaN
# Cafeteria cenidet            NaN    NaN    NaN  ...    NaN    NaN    NaN
#
# userID                     U1132  U1133  U1134  U1135  U1136  U1137  U1138
# name
# Abondance Restaurante Bar    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Arrachela Grill              NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Cabana Huasteca              NaN    NaN    2.0    NaN    NaN    NaN    NaN
# Cafe Chaires                 NaN    NaN    0.0    NaN    NaN    NaN    NaN
# Cafeteria cenidet            NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# [5 rows x 138 columns]

# %% [markdown]
# ***Análisis:*** Se construyó la matriz de utilidad UtMx_rating, compuesta por 130 restaurantes y 138 usuarios. Cada entrada de la matriz representa la calificación general asignada por un usuario a un restaurante. Los valores faltantes (NaN) corresponden a combinaciones usuario-restaurante para las cuales no existe una evaluación registrada. Esta estructura constituye la base para la aplicación de técnicas de filtrado colaborativo y factorización matricial, permitiendo descubrir patrones latentes en las preferencias de los usuarios

# %% [markdown]
# #### **Similaridades con la matriz obtenida de la Factorización SVD Truncada:**

# %% [markdown]
# *   ### **Aplicaremo la Factorización SVD con los 66 primeros valores singulares a la matriz de utilidad UtMx_rating.**
#
# *   ### **El valor de 66 se seleccionó porque esta cantidad de valores singulares es suficiente para describir al menos el 95% de la varianza de la matriz de utilidad (información que mostraremos a continuación).**
#
# *   ### **Recordemos que la factorización SVD de una matriz $A$ tiene la forma:** $A_{m\times n} = U_{m\times m}\Sigma_{m\times n}V_{n\times n}^T$
#
# *   ### **Usaremos la función coseno como medida de similaridad**
#
# *   ### **Usaremos el sistema de recomendación construído con SVD para buscar restaurantes similares al restaurante llamado  "tacos de barbacoa enfrente del Tec"**.

# %%
from sklearn.decomposition import TruncatedSVD
from sklearn.metrics.pairwise import cosine_similarity

num_componentes=66  # componentes más significativas

UtMx_rating = UtMx_rating.fillna(0)

# Obtengamos la matriz de factores latentes de los restaurantes:
SVD_rating = TruncatedSVD(n_components=num_componentes)  # inicializamos
matriz_latente_restaurantes = SVD_rating.fit_transform(UtMx_rating) # SVD truncada-ndarray

print('Dimensión Vectores latentes restaurantes:', matriz_latente_restaurantes.shape)
print('Dimensión Traspuesta Vectores latentes usuarios:', SVD_rating.components_.shape)

# Calculemos la variabilidad acumulada de las componentes utilizadas:
print('\nVariabilidad acumulada de las componentes utilizadas: %.3f' % SVD_rating.explained_variance_ratio_[0:num_componentes].sum())

# matriz de similaridad
sim_matrix = cosine_similarity(matriz_latente_restaurantes)

# Restaurante de referencia:
restaurante_de_referencia = "tacos de barbacoa enfrente del Tec"
nombres_rest = UtMx_rating.T.columns  # lista de los nombres de los restaurantes.
idx_rest = list(nombres_rest).index(restaurante_de_referencia) # índice del restaurante de referencia.
sim_vector = sim_matrix[idx_rest] # Vector de similaridad del restaurante de referencia contra todos.

# Buscando las similaridades positivas:
idx = (sim_vector>0)
mejores_sim_rate = list()
for i in range(len(nombres_rest[idx])):
  mejores_sim_rate.append((sim_vector[idx][i], nombres_rest[idx][i]))

print('\nTotal de similaridades positivas encontradas:', len(mejores_sim_rate))

# Las ordenamos de mayor a menor relevancia:
mejores_sim_rate_ordenadas = sorted(mejores_sim_rate, key=lambda x:x[0], reverse=True)

print('\nMejores recomendaciones con base al restaurante: \"%s\":' % restaurante_de_referencia)
mejores_sim_rate_ordenadas[1:11]   # omitimos el primero que es el mismo restaurante de referencia
# Out:
# Dimensión Vectores latentes restaurantes: (130, 66)
# Dimensión Traspuesta Vectores latentes usuarios: (66, 138)
#
# Variabilidad acumulada de las componentes utilizadas: 0.952
#
# Total de similaridades positivas encontradas: 72
#
# Mejores recomendaciones con base al restaurante: "tacos de barbacoa enfrente del Tec":
# [(np.float64(0.9371933547875138), 'vips'),
#  (np.float64(0.9340627313925374), 'little pizza Emilio Portes Gil'),
#  (np.float64(0.92540553812255), 'tacos abi'),
#  (np.float64(0.5308870552112563), 'Carreton de Flautas y Migadas'),
#  (np.float64(0.5016836867765402), 'puesto de gorditas'),
#  (np.float64(0.47904779323607016), 'Taqueria EL amigo '),
#  (np.float64(0.3639864183572804), 'carnitas_mata'),
#  (np.float64(0.26272475275276996), 'Little Cesarz'),
#  (np.float64(0.23409154405469765), 'Gorditas Dona Tota 2'),
#  (np.float64(0.18302199998742114), 'carnitas mata calle Emilio Portes Gil')]

# %% [markdown]
# ***análisis:*** Se aplicó la factorización SVD truncada utilizando 66 componentes principales, logrando preservar aproximadamente el 95.2 % de la variabilidad de la matriz de utilidad. Posteriormente, se calculó la similitud coseno entre los vectores latentes de los restaurantes, lo que permitió identificar aquellos establecimientos con patrones de evaluación semejantes al restaurante de referencia "tacos de barbacoa enfrente del Tec". Como resultado, se obtuvieron diez recomendaciones basadas en la similitud de preferencias observadas en los usuarios.
#
#
#
# La factorización matricial mediante SVD permite descubrir factores latentes que representan las preferencias subyacentes de los usuarios y las características de los ítems. Posteriormente, la similitud coseno puede utilizarse para medir la proximidad entre dichos vectores latentes y generar recomendaciones personalizadas (Ricci, Rokach, & Shapira, 2022).
#
# ***Referencia:.***
#
# Ricci, F., Rokach, L., & Shapira, B. (2022). Recommender Systems Handbook (3.ª ed.). Springer. https://doi.org/10.1007/978-1-0716-2197-4

# %% [markdown]
# # **Ejercicio - 5**

# %% [markdown]
# ### **Sistema de Recomendación Híbrido**
#
# * ### **Construyamos ahora un sistema de recomendación híbrido, el cual consistirá en conjuntar "matriz_latente_restaurantes" (que es un ndarray) obtenida previamente, con la matriz de factores adicionales (que también será un ndarray) formada por las columnas One-Hot-Encoder de los factores 'dress_code', 'accessibility', 'price' y 'franchise' del DataFrame data_geo.**
#
# * ### **Los renglones de la matriz híbrida siguen representando a cada restaurante diferente, pero ahora con la información conjunta de los vectores latentes de la factorización SVD, junto con los vectores OneHotEncoding de los nuevos factores que incluídos. Esta combinación de información es una de las técnicas clásicas para contruir sistemas de recomendación más robustos.**

# %%
# Ejercicio 5:

# Define el DataFrame "df_fact_adicionales" formada por los factores 'dress_code',
# 'accessibility', 'price' y 'franchise'.
# Después genera la matriz (ndarray), "matriz_factores_adicionales_ohe", que se obtiene
# al transformar las columnas (variables categóricas nominales) de "df_fact_adicionales"
# mediante OneHotEncoding.
# Finalmente conjuntar horizontalmente la matriz "matriz_latente_restaurantes"
# con "matriz_factores_adicionales_ohe" para obtener la "matriz_hibrida" (ndarray).
# Toma en cuenta que "matriz_hibrida" estará formada por las columnas de
# "matriz_latente_restaurantes" seguida por las columnas de "mat_fact_adicionales_ohe".


# ************* Inlcuye aquí tu código:*****************************

from sklearn.preprocessing import OneHotEncoder
import numpy as np

df_fact_adicionales = data_geo[['dress_code', 'accessibility', 'price', 'franchise']]

encoder = OneHotEncoder(sparse_output=False)

matriz_factores_adicionales_ohe =encoder.fit_transform(df_fact_adicionales)
matriz_hibrida = np.hstack((matriz_latente_restaurantes, matriz_factores_adicionales_ohe))




# *********** Aquí termina la sección de agregar código *************


print('Dimensión de la matriz híbrida:')
matriz_hibrida.shape
# Out:
# Dimensión de la matriz híbrida:
# (130, 77)

# %%
# Recordemos que "restaurante_de_referencia" es "tacos de barbacoa enfrente del Tec".
# Obtenengamos el índice de este restaurante:

idx = data_geo[data_geo['name'] == restaurante_de_referencia].index[0]

print('Restaurante de referencia:', restaurante_de_referencia)
print('Índice del restaurante de referencia:', idx)
# Out:
# Restaurante de referencia: tacos de barbacoa enfrente del Tec
# Índice del restaurante de referencia: 111

# %% [markdown]
# ***Análisis:*** Se identificó el restaurante de referencia denominado "tacos de barbacoa enfrente del Tec" dentro del conjunto de datos y se determinó que su índice correspondiente es 111. La localización de este índice es fundamental, ya que permite acceder a la fila asociada al restaurante en la matriz híbrida y calcular posteriormente las similitudes con los demás establecimientos. De esta manera, el sistema de recomendación puede comparar las características latentes obtenidas mediante SVD y los atributos adicionales incorporados mediante One-Hot Encoding para identificar restaurantes con perfiles similares y generar recomendaciones personalizadas.

# %% [markdown]
# # **Ejercicio - 6:**

# %% [markdown]
# * ### **Ahora que tienes la matriz híbrida, con dicha matriz obtener las similitudes (con respecto a la función coseno) del restaurante de referencia "tacos de barbacoa enfrente del Tec" con relación a todos los restaurantes. Deberás desplegar los primeros 10 restaurantes de mayor similitud (sin incluir al restaurante de referencia mismo), ordenados de mayor a menor similitud, y también desplegando el valor de similitud mismo.**

# %%
# Ejercicio 6

# ************* Inlcuye aquí tu código:*****************************


# Matriz de similitud utilizando la matriz híbrida
sim_matriz_hibrida = cosine_similarity(matriz_hibrida)

# Vector de similitud del restaurante de referencia
sim_vector_hibrido = sim_matriz_hibrida[idx]


df_similitudes = pd.DataFrame({
    'Restaurante': data_geo['name'],
    'Similitud': sim_vector_hibrido
})

# Eliminamos el restaurante de referencia
df_similitudes = df_similitudes[df_similitudes['Restaurante'] != restaurante_de_referencia]

# Mayor a menor similitud
df_similitudes = df_similitudes.sort_values(
    by='Similitud',
    ascending=False
)

# Redondeamos la similitud
df_similitudes['Similitud'] = df_similitudes['Similitud'].round(4)

# Desplegamos las 10 mejores recomendaciones
print(f'Top 10 restaurantes más similares a "{restaurante_de_referencia}":')

df_similitudes.head(10)



# *********** Aquí termina la sección de agregar código *************
# Out:
# Top 10 restaurantes más similares a "tacos de barbacoa enfrente del Tec":
#                         Restaurante  Similitud
# 71                  Arrachela Grill     0.4656
# 73                       palomo tec     0.4519
# 90                  Pizzeria Julios     0.4446
# 76               TACOS CORRECAMINOS     0.4259
# 118            Gorditas Dona Tota 2     0.4171
# 83                     tortas hawai     0.4041
# 15   Tortas y hamburguesas el gordo     0.3821
# 48                             Vips     0.3814
# 122                       tacos abi     0.3737
# 53       Michiko Restaurant Japones     0.3467

# %% [markdown]
# ***Análisis:*** El sistema de recomendación híbrido permitió identificar los diez restaurantes más similares a "tacos de barbacoa enfrente del Tec", destacándose Arrachera Grill, palomo tec y Pizzeria Julios como las recomendaciones más cercanas. Los valores de similitud obtenidos evidencian la capacidad del modelo para combinar las preferencias de los usuarios y las características propias de los restaurantes, proporcionando recomendaciones más precisas.

# %% [markdown]
# # **Ejercicio - 7**

# %% [markdown]
# ### **Incluye tus comentarios y conclusiones de la actividad.**

# %% [markdown]
# ++++++++ Inicia la sección de agregar texto: +++++++++++
#
# ***Análisis general***
#
# Durante el desarrollo de esta actividad se construyó un sistema de recomendación híbrido para restaurantes utilizando técnicas de aprendizaje automático. Inicialmente, se realizó el preprocesamiento de los datos y la integración de la información proveniente de diferentes fuentes para construir una matriz de utilidad que representa las evaluaciones de los usuarios hacia los restaurantes.
#
# Posteriormente, se aplicó la Descomposición en Valores Singulares (SVD), utilizando 66 componentes principales, logrando conservar aproximadamente el 95.2 % de la variabilidad de la información. Esta técnica permitió obtener factores latentes que representan patrones ocultos en las preferencias de los usuarios. Adicionalmente, se incorporaron características propias de los restaurantes mediante la técnica One-Hot Encoding, dando lugar a una matriz híbrida que combina información colaborativa y basada en contenido.
#
# A partir de esta representación híbrida y utilizando la similitud coseno, fue posible identificar los restaurantes con mayor semejanza al restaurante de referencia "tacos de barbacoa enfrente del Tec", obteniéndose recomendaciones consistentes y acordes con las características de los establecimientos.
#
# La actividad permitió comprender la importancia de la integración de diferentes fuentes de información en los sistemas de recomendación y evidenció que los modelos híbridos ofrecen una alternativa más robusta y precisa que los enfoques tradicionales, al aprovechar tanto las preferencias de los usuarios como las características descriptivas de los ítems. Según Ricci, Rokach y Shapira (2022), los sistemas híbridos representan una de las estrategias más efectivas para mejorar la calidad y precisión de las recomendaciones.
#
#
#
# ++++++++ Termina la sección de agregar texto. +++++++++++

# %% [markdown]
# # **++++ Fin de la Actividad de la semana: Sistema de Recomendación Híbrido +++**
